# %% [markdown]
# ### Linear programming
# Linear programming is an optimization technique for a system of linear constraints and a linear objective function. An objective function defines the quantity to be optimized, and the goal of linear programming is to find the values of the variables that maximize or minimize the objective function.
# Linear programming is useful for many problems that require an optimization of resources. It could be applied to manufacturing, to calculate how to assign labor and machinery to minimize cost of operations. It could be applied in high-level business operations, to decide which products to sell and in what quantity in order to maximize profit. It could also be applied in logistics, to decide how to apply resources to get a job done in the minimum amount of time.
# Good introduction you can use here: https://brilliant.org/wiki/linear-programming/
#
# Here we created one interesting task to illustrate LP problem.

# %%
import pandas as pd
import numpy as np
from gurobipy import *

# %% [markdown]
# ### Task description
# Imagine you are local community officer in new suburban municipality and you need to hire teachers for new schools. You are responsible for ten schools and you have asked the teachers where they live. You have read an article that people are more motivated for a job if they do not have to travell a long way, so you want to hire teachers in the school which is the nearest to their home. Also, teachers have some salary expectations and you have some budget constraints. Every school needs one new teacher. How would you solve this? By linear programming! But, let's create some fake data first.

# %%
# Let's create the list of the teachers first:
teachers = []
for i in range(1,101):
    teachers.append(f'teacher_{i}')

# %%
#then schools
schools = []
for i in range(1,11):
    schools.append(f'School_{i}')

# %%
#now we will for each teacher and school create some fake distance that in maximum could be 20 km
distances = []
for teacher in teachers:
    for school in schools:
        distances.append(np.random.randint(2, 20, size=1))
len(distances)
# Out:
# 1000

# %%
values = np.asarray(distances).reshape(100,-10)
df = pd.DataFrame(values, index=teachers, columns = schools)

# %%
df
# Out:
#              School_1  School_2  School_3  School_4  School_5  School_6  \
# teacher_1           4        14         6        15        16        16
# teacher_2           5         8         6        17         9        18
# teacher_3          18        13        10        17         7        17
# teacher_4           4         4         2        11        19         6
# teacher_5           3        15         2         2         3        15
# ...               ...       ...       ...       ...       ...       ...
# teacher_96          9        11        10        11         9        12
# teacher_97          8        13        14        17         4         3
# teacher_98          7        15        15        17        10        11
# teacher_99         13        15        11        14        12         3
# teacher_100        18         7        17         6        10         3
#
#              School_7  School_8  School_9  School_10
# teacher_1          11         8        17         14
# teacher_2          17         7        15          9
# teacher_3           7        19         5          2
# teacher_4           7         7        11         17
# teacher_5           9        16        15          2
# ...               ...       ...       ...        ...
# teacher_96         11        16         9          6
# teacher_97         14         6         9          7
# teacher_98          5        17        17         12
# teacher_99         11         6         3         15
# teacher_100         8        15        16         16
#
# [100 rows x 10 columns]

# %%
#At the end, let's add some fake salary expectaitons for each teacher, maximal teacher salary could be 8000 dollars
salary_expectation = []
for i in range(1,101):
    salary_expectation.append(np.random.randint(8000, size=1))
salary_expectation = np.asarray(salary_expectation).reshape(100,)

# %%
salary_pd = pd.Series(salary_expectation, index = df.index)

# %%
df['salary_expectation'] = salary_pd

# %%
#We must also calculate total distance for each teacher which we will use for objective function (we sum all school distances for each teacher)
df['total_distance'] = df.iloc[:,:-2].sum(axis=1)

# %%
df.head()
# Out:
#            School_1  School_2  School_3  School_4  School_5  School_6  \
# teacher_1         4        14         6        15        16        16
# teacher_2         5         8         6        17         9        18
# teacher_3        18        13        10        17         7        17
# teacher_4         4         4         2        11        19         6
# teacher_5         3        15         2         2         3        15
#
#            School_7  School_8  School_9  School_10  salary_expectation  \
# teacher_1        11         8        17         14                5820
# teacher_2        17         7        15          9                1251
# teacher_3         7        19         5          2                1815
# teacher_4         7         7        11         17                6253
# teacher_5         9        16        15          2                4521
#
#            total_distance
# teacher_1             107
# teacher_2             102
# teacher_3             113
# teacher_4              71
# teacher_5              80

# %%
#Declare and initialise the model
#Resource Assignment problem - RAP
#Four components of the model: data, desicion variables, constraints and objective function

m = Model('RAP')
# Out:
# Restricted license - for non-production use only - expires 2023-10-25

# %%
from itertools import product

combinations = list(product(teachers, schools))
combinations[:10]
# Out:
# [('teacher_1', 'School_1'),
#  ('teacher_1', 'School_2'),
#  ('teacher_1', 'School_3'),
#  ('teacher_1', 'School_4'),
#  ('teacher_1', 'School_5'),
#  ('teacher_1', 'School_6'),
#  ('teacher_1', 'School_7'),
#  ('teacher_1', 'School_8'),
#  ('teacher_1', 'School_9'),
#  ('teacher_1', 'School_10')]

# %%
# x is our decistion variable, in this case it could be only 1 (meaning this teacher goes to this school) or 0 (not assigned to this school)
# in combinations we created all possible combinations of each teacher and each school
x = m.addVars(combinations, name='assign')

# %%
#now we create constraint that teacher can be assigned only to one school
jobs = m.addConstrs((x.sum('*',school)==1 for school in schools), 'job')

# %%
# for all teachers in the list of teachers with index j must be less 1, i.e. some teachers could not be chosen
#teachers must be assigned maximum to 1 job, but it could happen teacher will not be chosen at all if he or she lives to far
# or have unrealistic salary expectation
resources = m.addConstrs((x.sum(teacher,'*')<=1 for teacher in teachers), 'teacher')

# %%
# just transform salary expectation to dict for gurobypi for budget constraint 
cost = {}
for i, teacher in enumerate(teachers):
    for j, school in enumerate(schools):
        cost[(teacher,school)] = df['salary_expectation'][i]

# %%
#We also have some budget constraint. Out total budget is 400 000 dolars. So salary expectations of selected teachers
#must not exceed 4000 000 dollars.
budget = 400000
budget = m.addConstr((x.prod(cost)<=budget), 'budget')

# %%
# now we transpose our pandas data frame in multidict gurobipy could use 
obj_func = {}
for i, teacher in enumerate(teachers):
    for j, school in enumerate(schools):
        obj_func[(teacher,school)] = df.iloc[i,j]

# %%
len(obj_func)
# Out:
# 1000

# %%
obj_func
# Out:
# {('teacher_1', 'School_1'): 4,
#  ('teacher_1', 'School_2'): 14,
#  ('teacher_1', 'School_3'): 6,
#  ('teacher_1', 'School_4'): 15,
#  ('teacher_1', 'School_5'): 16,
#  ('teacher_1', 'School_6'): 16,
#  ('teacher_1', 'School_7'): 11,
#  ('teacher_1', 'School_8'): 8,
#  ('teacher_1', 'School_9'): 17,
#  ('teacher_1', 'School_10'): 14,
#  ('teacher_2', 'School_1'): 5,
#  ('teacher_2', 'School_2'): 8,
#  ('teacher_2', 'School_3'): 6,
#  ('teacher_2', 'School_4'): 17,
#  ('teacher_2', 'School_5'): 9,
#  ('teacher_2', 'School_6'): 18,
#  ('teacher_2', 'School_7'): 17,
#  ('teacher_2', 'School_8'): 7,
#  ('teacher_2', 'School_9'): 15,
#  ('teacher_2', 'School_10'): 9,
#  ('teacher_3', 'School_1'): 18,
#  ('teacher_3', 'School_2'): 13,
#  ('teacher_3', 'School_3'): 10,
#  ('teacher_3', 'School_4'): 17,
#  ('teacher_3', 'School_5'): 7,
#  ('teacher_3', 'School_6'): 17,
#  ('teacher_3', 'School_7'): 7,
#  ('teacher_3', 'School_8'): 19,
#  ('teacher_3', 'School_9'): 5,
#  ('teacher_3', 'School_10'): 2,
#  ('teacher_4', 'School_1'): 4,
#  ('teacher_4', 'School_2'): 4,
#  ('teacher_4', 'School_3'): 2,
#  ('teacher_4', 'School_4'): 11,
#  ('teacher_4', 'School_5'): 19,
#  ('teacher_4', 'School_6'): 6,
#  ('teacher_4', 'School_7'): 7,
#  ('teacher_4', 'School_8'): 7,
#  ('teacher_4', 'School_9'): 11,
#  ('teacher_4', 'School_10'): 17,
#  ('teacher_5', 'School_1'): 3,
#  ('teacher_5', 'School_2'): 15,
#  ('teacher_5', 'School_3'): 2,
#  ('teacher_5', 'School_4'): 2,
#  ('teacher_5', 'School_5'): 3,
#  ('teacher_5', 'School_6'): 15,
#  ('teacher_5', 'School_7'): 9,
#  ('teacher_5', 'School_8'): 16,
#  ('teacher_5', 'School_9'): 15,
#  ('teacher_5', 'School_10'): 2,
#  ('teacher_6', 'School_1'): 16,
#  ('teacher_6', 'School_2'): 2,
#  ('teacher_6', 'School_3'): 8,
#  ('teacher_6', 'School_4'): 11,
#  ('teacher_6', 'School_5'): 15,
#  ('teacher_6', 'School_6'): 15,
#  ('teacher_6', 'School_7'): 2,
#  ('teacher_6', 'School_8'): 9,
#  ('teacher_6', 'School_9'): 6,
#  ('teacher_6', 'School_10'): 11,
#  ('teacher_7', 'School_1'): 7,
#  ('teacher_7', 'School_2'): 15,
#  ('teacher_7', 'School_3'): 18,
#  ('teacher_7', 'School_4'): 9,
#  ('teacher_7', 'School_5'): 10,
#  ('teacher_7', 'School_6'): 6,
#  ('teacher_7', 'School_7'): 5,
#  ('teacher_7', 'School_8'): 17,
#  ('teacher_7', 'School_9'): 2,
#  ('teacher_7', 'School_10'): 9,
#  ('teacher_8', 'School_1'): 10,
#  ('teacher_8', 'School_2'): 14,
#  ('teacher_8', 'School_3'): 12,
#  ('teacher_8', 'School_4'): 11,
#  ('teacher_8', 'School_5'): 6,
#  ('teacher_8', 'School_6'): 17,
#  ('teacher_8', 'School_7'): 18,
#  ('teacher_8', 'School_8'): 9,
#  ('teacher_8', 'School_9'): 18,
#  ('teacher_8', 'School_10'): 7,
#  ('teacher_9', 'School_1'): 16,
#  ('teacher_9', 'School_2'): 15,
#  ('teacher_9', 'School_3'): 18,
#  ('teacher_9', 'School_4'): 16,
#  ('teacher_9', 'School_5'): 7,
#  ('teacher_9', 'School_6'): 5,
#  ('teacher_9', 'School_7'): 5,
#  ('teacher_9', 'School_8'): 13,
#  ('teacher_9', 'School_9'): 9,
#  ('teacher_9', 'School_10'): 5,
#  ('teacher_10', 'School_1'): 11,
#  ('teacher_10', 'School_2'): 14,
#  ('teacher_10', 'School_3'): 6,
#  ('teacher_10', 'School_4'): 16,
#  ('teacher_10', 'School_5'): 12,
#  ('teacher_10', 'School_6'): 9,
#  ('teacher_10', 'School_7'): 10,
#  ('teacher_10', 'School_8'): 17,
#  ('teacher_10', 'School_9'): 13,
#  ('teacher_10', 'School_10'): 9,
#  ('teacher_11', 'School_1'): 18,
#  ('teacher_11', 'School_2'): 4,
#  ('teacher_11', 'School_3'): 8,
#  ('teacher_11', 'School_4'): 14,
#  ('teacher_11', 'School_5'): 5,
#  ('teacher_11', 'School_6'): 5,
#  ('teacher_11', 'School_7'): 8,
#  ('teacher_11', 'School_8'): 5,
#  ('teacher_11', 'School_9'): 15,
#  ('teacher_11', 'School_10'): 2,
#  ('teacher_12', 'School_1'): 2,
#  ('teacher_12', 'School_2'): 5,
#  ('teacher_12', 'School_3'): 11,
#  ('teacher_12', 'School_4'): 16,
#  ('teacher_12', 'School_5'): 3,
#  ('teacher_12', 'School_6'): 13,
#  ('teacher_12', 'School_7'): 11,
#  ('teacher_12', 'School_8'): 4,
#  ('teacher_12', 'School_9'): 13,
#  ('teacher_12', 'School_10'): 6,
#  ('teacher_13', 'School_1'): 17,
#  ('teacher_13', 'School_2'): 6,
#  ('teacher_13', 'School_3'): 4,
#  ('teacher_13', 'School_4'): 12,
#  ('teacher_13', 'School_5'): 17,
#  ('teacher_13', 'School_6'): 6,
#  ('teacher_13', 'School_7'): 13,
#  ('teacher_13', 'School_8'): 10,
#  ('teacher_13', 'School_9'): 12,
#  ('teacher_13', 'School_10'): 10,
#  ('teacher_14', 'School_1'): 12,
#  ('teacher_14', 'School_2'): 11,
#  ('teacher_14', 'School_3'): 18,
#  ('teacher_14', 'School_4'): 8,
#  ('teacher_14', 'School_5'): 6,
#  ('teacher_14', 'School_6'): 14,
#  ('teacher_14', 'School_7'): 14,
#  ('teacher_14', 'School_8'): 11,
#  ('teacher_14', 'School_9'): 12,
#  ('teacher_14', 'School_10'): 13,
#  ('teacher_15', 'School_1'): 8,
#  ('teacher_15', 'School_2'): 19,
#  ('teacher_15', 'School_3'): 7,
#  ('teacher_15', 'School_4'): 12,
#  ('teacher_15', 'School_5'): 6,
#  ('teacher_15', 'School_6'): 6,
#  ('teacher_15', 'School_7'): 9,
#  ('teacher_15', 'School_8'): 8,
#  ('teacher_15', 'School_9'): 8,
#  ('teacher_15', 'School_10'): 15,
#  ('teacher_16', 'School_1'): 15,
#  ('teacher_16', 'School_2'): 3,
#  ('teacher_16', 'School_3'): 5,
#  ('teacher_16', 'School_4'): 9,
#  ('teacher_16', 'School_5'): 7,
#  ('teacher_16', 'School_6'): 2,
#  ('teacher_16', 'School_7'): 4,
#  ('teacher_16', 'School_8'): 12,
#  ('teacher_16', 'School_9'): 8,
#  ('teacher_16', 'School_10'): 3,
#  ('teacher_17', 'School_1'): 7,
#  ('teacher_17', 'School_2'): 6,
#  ('teacher_17', 'School_3'): 14,
#  ('teacher_17', 'School_4'): 11,
#  ('teacher_17', 'School_5'): 13,
#  ('teacher_17', 'School_6'): 15,
#  ('teacher_17', 'School_7'): 3,
#  ('teacher_17', 'School_8'): 18,
#  ('teacher_17', 'School_9'): 2,
#  ('teacher_17', 'School_10'): 6,
#  ('teacher_18', 'School_1'): 9,
#  ('teacher_18', 'School_2'): 5,
#  ('teacher_18', 'School_3'): 18,
#  ('teacher_18', 'School_4'): 3,
#  ('teacher_18', 'School_5'): 2,
#  ('teacher_18', 'School_6'): 5,
#  ('teacher_18', 'School_7'): 12,
#  ('teacher_18', 'School_8'): 12,
#  ('teacher_18', 'School_9'): 5,
#  ('teacher_18', 'School_10'): 16,
#  ('teacher_19', 'School_1'): 13,
#  ('teacher_19', 'School_2'): 6,
#  ('teacher_19', 'School_3'): 6,
#  ('teacher_19', 'School_4'): 18,
#  ('teacher_19', 'School_5'): 5,
#  ('teacher_19', 'School_6'): 13,
#  ('teacher_19', 'School_7'): 6,
#  ('teacher_19', 'School_8'): 17,
#  ('teacher_19', 'School_9'): 7,
#  ('teacher_19', 'School_10'): 8,
#  ('teacher_20', 'School_1'): 16,
#  ('teacher_20', 'School_2'): 11,
#  ('teacher_20', 'School_3'): 13,
#  ('teacher_20', 'School_4'): 6,
#  ('teacher_20', 'School_5'): 11,
#  ('teacher_20', 'School_6'): 13,
#  ('teacher_20', 'School_7'): 14,
#  ('teacher_20', 'School_8'): 2,
#  ('teacher_20', 'School_9'): 12,
#  ('teacher_20', 'School_10'): 14,
#  ('teacher_21', 'School_1'): 15,
#  ('teacher_21', 'School_2'): 13,
#  ('teacher_21', 'School_3'): 11,
#  ('teacher_21', 'School_4'): 15,
#  ('teacher_21', 'School_5'): 10,
#  ('teacher_21', 'School_6'): 19,
#  ('teacher_21', 'School_7'): 5,
#  ('teacher_21', 'School_8'): 15,
#  ('teacher_21', 'School_9'): 10,
#  ('teacher_21', 'School_10'): 3,
#  ('teacher_22', 'School_1'): 4,
#  ('teacher_22', 'School_2'): 17,
#  ('teacher_22', 'School_3'): 13,
#  ('teacher_22', 'School_4'): 17,
#  ('teacher_22', 'School_5'): 16,
#  ('teacher_22', 'School_6'): 15,
#  ('teacher_22', 'School_7'): 10,
#  ('teacher_22', 'School_8'): 17,
#  ('teacher_22', 'School_9'): 9,
#  ('teacher_22', 'School_10'): 5,
#  ('teacher_23', 'School_1'): 7,
#  ('teacher_23', 'School_2'): 5,
#  ('teacher_23', 'School_3'): 3,
#  ('teacher_23', 'School_4'): 12,
#  ('teacher_23', 'School_5'): 16,
#  ('teacher_23', 'School_6'): 5,
#  ('teacher_23', 'School_7'): 2,
#  ('teacher_23', 'School_8'): 15,
#  ('teacher_23', 'School_9'): 6,
#  ('teacher_23', 'School_10'): 7,
#  ('teacher_24', 'School_1'): 19,
#  ('teacher_24', 'School_2'): 18,
#  ('teacher_24', 'School_3'): 9,
#  ('teacher_24', 'School_4'): 4,
#  ('teacher_24', 'School_5'): 15,
#  ('teacher_24', 'School_6'): 15,
#  ('teacher_24', 'School_7'): 17,
#  ('teacher_24', 'School_8'): 9,
#  ('teacher_24', 'School_9'): 7,
#  ('teacher_24', 'School_10'): 16,
#  ('teacher_25', 'School_1'): 6,
#  ('teacher_25', 'School_2'): 8,
#  ('teacher_25', 'School_3'): 18,
#  ('teacher_25', 'School_4'): 18,
#  ('teacher_25', 'School_5'): 18,
#  ('teacher_25', 'School_6'): 3,
#  ('teacher_25', 'School_7'): 16,
#  ('teacher_25', 'School_8'): 10,
#  ('teacher_25', 'School_9'): 14,
#  ('teacher_25', 'School_10'): 4,
#  ('teacher_26', 'School_1'): 16,
#  ('teacher_26', 'School_2'): 14,
#  ('teacher_26', 'School_3'): 6,
#  ('teacher_26', 'School_4'): 11,
#  ('teacher_26', 'School_5'): 9,
#  ('teacher_26', 'School_6'): 12,
#  ('teacher_26', 'School_7'): 10,
#  ('teacher_26', 'School_8'): 11,
#  ('teacher_26', 'School_9'): 16,
#  ('teacher_26', 'School_10'): 3,
#  ('teacher_27', 'School_1'): 6,
#  ('teacher_27', 'School_2'): 14,
#  ('teacher_27', 'School_3'): 6,
#  ('teacher_27', 'School_4'): 10,
#  ('teacher_27', 'School_5'): 5,
#  ('teacher_27', 'School_6'): 10,
#  ('teacher_27', 'School_7'): 3,
#  ('teacher_27', 'School_8'): 5,
#  ('teacher_27', 'School_9'): 14,
#  ('teacher_27', 'School_10'): 9,
#  ('teacher_28', 'School_1'): 18,
#  ('teacher_28', 'School_2'): 2,
#  ('teacher_28', 'School_3'): 16,
#  ('teacher_28', 'School_4'): 18,
#  ('teacher_28', 'School_5'): 4,
#  ('teacher_28', 'School_6'): 15,
#  ('teacher_28', 'School_7'): 18,
#  ('teacher_28', 'School_8'): 10,
#  ('teacher_28', 'School_9'): 6,
#  ('teacher_28', 'School_10'): 16,
#  ('teacher_29', 'School_1'): 11,
#  ('teacher_29', 'School_2'): 8,
#  ('teacher_29', 'School_3'): 17,
#  ('teacher_29', 'School_4'): 19,
#  ('teacher_29', 'School_5'): 3,
#  ('teacher_29', 'School_6'): 18,
#  ('teacher_29', 'School_7'): 7,
#  ('teacher_29', 'School_8'): 7,
#  ('teacher_29', 'School_9'): 2,
#  ('teacher_29', 'School_10'): 18,
#  ('teacher_30', 'School_1'): 8,
#  ('teacher_30', 'School_2'): 6,
#  ('teacher_30', 'School_3'): 4,
#  ('teacher_30', 'School_4'): 5,
#  ('teacher_30', 'School_5'): 17,
#  ('teacher_30', 'School_6'): 15,
#  ('teacher_30', 'School_7'): 7,
#  ('teacher_30', 'School_8'): 13,
#  ('teacher_30', 'School_9'): 3,
#  ('teacher_30', 'School_10'): 16,
#  ('teacher_31', 'School_1'): 10,
#  ('teacher_31', 'School_2'): 3,
#  ('teacher_31', 'School_3'): 14,
#  ('teacher_31', 'School_4'): 16,
#  ('teacher_31', 'School_5'): 11,
#  ('teacher_31', 'School_6'): 16,
#  ('teacher_31', 'School_7'): 6,
#  ('teacher_31', 'School_8'): 18,
#  ('teacher_31', 'School_9'): 4,
#  ('teacher_31', 'School_10'): 8,
#  ('teacher_32', 'School_1'): 5,
#  ('teacher_32', 'School_2'): 14,
#  ('teacher_32', 'School_3'): 14,
#  ('teacher_32', 'School_4'): 6,
#  ('teacher_32', 'School_5'): 12,
#  ('teacher_32', 'School_6'): 11,
#  ('teacher_32', 'School_7'): 17,
#  ('teacher_32', 'School_8'): 7,
#  ('teacher_32', 'School_9'): 5,
#  ('teacher_32', 'School_10'): 17,
#  ('teacher_33', 'School_1'): 2,
#  ('teacher_33', 'School_2'): 2,
#  ('teacher_33', 'School_3'): 13,
#  ('teacher_33', 'School_4'): 16,
#  ('teacher_33', 'School_5'): 3,
#  ('teacher_33', 'School_6'): 14,
#  ('teacher_33', 'School_7'): 10,
#  ('teacher_33', 'School_8'): 15,
#  ('teacher_33', 'School_9'): 5,
#  ('teacher_33', 'School_10'): 17,
#  ('teacher_34', 'School_1'): 16,
#  ('teacher_34', 'School_2'): 19,
#  ('teacher_34', 'School_3'): 14,
#  ('teacher_34', 'School_4'): 9,
#  ('teacher_34', 'School_5'): 11,
#  ('teacher_34', 'School_6'): 15,
#  ('teacher_34', 'School_7'): 5,
#  ('teacher_34', 'School_8'): 8,
#  ('teacher_34', 'School_9'): 11,
#  ('teacher_34', 'School_10'): 12,
#  ('teacher_35', 'School_1'): 3,
#  ('teacher_35', 'School_2'): 16,
#  ('teacher_35', 'School_3'): 15,
#  ('teacher_35', 'School_4'): 15,
#  ('teacher_35', 'School_5'): 13,
#  ('teacher_35', 'School_6'): 13,
#  ('teacher_35', 'School_7'): 12,
#  ('teacher_35', 'School_8'): 10,
#  ('teacher_35', 'School_9'): 9,
#  ('teacher_35', 'School_10'): 7,
#  ('teacher_36', 'School_1'): 12,
#  ('teacher_36', 'School_2'): 11,
#  ('teacher_36', 'School_3'): 8,
#  ('teacher_36', 'School_4'): 4,
#  ('teacher_36', 'School_5'): 7,
#  ('teacher_36', 'School_6'): 13,
#  ('teacher_36', 'School_7'): 10,
#  ('teacher_36', 'School_8'): 7,
#  ('teacher_36', 'School_9'): 10,
#  ('teacher_36', 'School_10'): 13,
#  ('teacher_37', 'School_1'): 3,
#  ('teacher_37', 'School_2'): 9,
#  ('teacher_37', 'School_3'): 4,
#  ('teacher_37', 'School_4'): 3,
#  ('teacher_37', 'School_5'): 15,
#  ('teacher_37', 'School_6'): 17,
#  ('teacher_37', 'School_7'): 3,
#  ('teacher_37', 'School_8'): 19,
#  ('teacher_37', 'School_9'): 13,
#  ('teacher_37', 'School_10'): 12,
#  ('teacher_38', 'School_1'): 18,
#  ('teacher_38', 'School_2'): 8,
#  ('teacher_38', 'School_3'): 7,
#  ('teacher_38', 'School_4'): 16,
#  ('teacher_38', 'School_5'): 12,
#  ('teacher_38', 'School_6'): 13,
#  ('teacher_38', 'School_7'): 5,
#  ('teacher_38', 'School_8'): 2,
#  ('teacher_38', 'School_9'): 9,
#  ('teacher_38', 'School_10'): 16,
#  ('teacher_39', 'School_1'): 4,
#  ('teacher_39', 'School_2'): 12,
#  ('teacher_39', 'School_3'): 5,
#  ('teacher_39', 'School_4'): 4,
#  ('teacher_39', 'School_5'): 14,
#  ('teacher_39', 'School_6'): 18,
#  ('teacher_39', 'School_7'): 14,
#  ('teacher_39', 'School_8'): 11,
#  ('teacher_39', 'School_9'): 17,
#  ('teacher_39', 'School_10'): 15,
#  ('teacher_40', 'School_1'): 6,
#  ('teacher_40', 'School_2'): 10,
#  ('teacher_40', 'School_3'): 9,
#  ('teacher_40', 'School_4'): 10,
#  ('teacher_40', 'School_5'): 18,
#  ('teacher_40', 'School_6'): 19,
#  ('teacher_40', 'School_7'): 9,
#  ('teacher_40', 'School_8'): 14,
#  ('teacher_40', 'School_9'): 8,
#  ('teacher_40', 'School_10'): 15,
#  ('teacher_41', 'School_1'): 3,
#  ('teacher_41', 'School_2'): 17,
#  ('teacher_41', 'School_3'): 7,
#  ('teacher_41', 'School_4'): 4,
#  ('teacher_41', 'School_5'): 8,
#  ('teacher_41', 'School_6'): 5,
#  ('teacher_41', 'School_7'): 7,
#  ('teacher_41', 'School_8'): 13,
#  ('teacher_41', 'School_9'): 16,
#  ('teacher_41', 'School_10'): 10,
#  ('teacher_42', 'School_1'): 17,
#  ('teacher_42', 'School_2'): 4,
#  ('teacher_42', 'School_3'): 12,
#  ('teacher_42', 'School_4'): 6,
#  ('teacher_42', 'School_5'): 8,
#  ('teacher_42', 'School_6'): 9,
#  ('teacher_42', 'School_7'): 2,
#  ('teacher_42', 'School_8'): 12,
#  ('teacher_42', 'School_9'): 19,
#  ('teacher_42', 'School_10'): 5,
#  ('teacher_43', 'School_1'): 17,
#  ('teacher_43', 'School_2'): 3,
#  ('teacher_43', 'School_3'): 4,
#  ('teacher_43', 'School_4'): 7,
#  ('teacher_43', 'School_5'): 17,
#  ('teacher_43', 'School_6'): 15,
#  ('teacher_43', 'School_7'): 12,
#  ('teacher_43', 'School_8'): 7,
#  ('teacher_43', 'School_9'): 16,
#  ('teacher_43', 'School_10'): 11,
#  ('teacher_44', 'School_1'): 10,
#  ('teacher_44', 'School_2'): 16,
#  ('teacher_44', 'School_3'): 6,
#  ('teacher_44', 'School_4'): 3,
#  ('teacher_44', 'School_5'): 2,
#  ('teacher_44', 'School_6'): 9,
#  ('teacher_44', 'School_7'): 15,
#  ('teacher_44', 'School_8'): 15,
#  ('teacher_44', 'School_9'): 9,
#  ('teacher_44', 'School_10'): 15,
#  ('teacher_45', 'School_1'): 9,
#  ('teacher_45', 'School_2'): 5,
#  ('teacher_45', 'School_3'): 18,
#  ('teacher_45', 'School_4'): 2,
#  ('teacher_45', 'School_5'): 2,
#  ('teacher_45', 'School_6'): 19,
#  ('teacher_45', 'School_7'): 12,
#  ('teacher_45', 'School_8'): 18,
#  ('teacher_45', 'School_9'): 15,
#  ('teacher_45', 'School_10'): 17,
#  ('teacher_46', 'School_1'): 7,
#  ('teacher_46', 'School_2'): 12,
#  ('teacher_46', 'School_3'): 19,
#  ('teacher_46', 'School_4'): 5,
#  ('teacher_46', 'School_5'): 10,
#  ('teacher_46', 'School_6'): 3,
#  ('teacher_46', 'School_7'): 17,
#  ('teacher_46', 'School_8'): 9,
#  ('teacher_46', 'School_9'): 10,
#  ('teacher_46', 'School_10'): 10,
#  ('teacher_47', 'School_1'): 7,
#  ('teacher_47', 'School_2'): 13,
#  ('teacher_47', 'School_3'): 17,
#  ('teacher_47', 'School_4'): 16,
#  ('teacher_47', 'School_5'): 18,
#  ('teacher_47', 'School_6'): 14,
#  ('teacher_47', 'School_7'): 3,
#  ('teacher_47', 'School_8'): 11,
#  ('teacher_47', 'School_9'): 19,
#  ('teacher_47', 'School_10'): 13,
#  ('teacher_48', 'School_1'): 9,
#  ('teacher_48', 'School_2'): 2,
#  ('teacher_48', 'School_3'): 6,
#  ('teacher_48', 'School_4'): 14,
#  ('teacher_48', 'School_5'): 8,
#  ('teacher_48', 'School_6'): 10,
#  ('teacher_48', 'School_7'): 5,
#  ('teacher_48', 'School_8'): 7,
#  ('teacher_48', 'School_9'): 16,
#  ('teacher_48', 'School_10'): 13,
#  ('teacher_49', 'School_1'): 9,
#  ('teacher_49', 'School_2'): 6,
#  ('teacher_49', 'School_3'): 7,
#  ('teacher_49', 'School_4'): 9,
#  ('teacher_49', 'School_5'): 8,
#  ('teacher_49', 'School_6'): 19,
#  ('teacher_49', 'School_7'): 4,
#  ('teacher_49', 'School_8'): 3,
#  ('teacher_49', 'School_9'): 13,
#  ('teacher_49', 'School_10'): 3,
#  ('teacher_50', 'School_1'): 3,
#  ('teacher_50', 'School_2'): 2,
#  ('teacher_50', 'School_3'): 8,
#  ('teacher_50', 'School_4'): 9,
#  ('teacher_50', 'School_5'): 16,
#  ('teacher_50', 'School_6'): 8,
#  ('teacher_50', 'School_7'): 19,
#  ('teacher_50', 'School_8'): 19,
#  ('teacher_50', 'School_9'): 6,
#  ('teacher_50', 'School_10'): 7,
#  ('teacher_51', 'School_1'): 17,
#  ('teacher_51', 'School_2'): 8,
#  ('teacher_51', 'School_3'): 9,
#  ('teacher_51', 'School_4'): 8,
#  ('teacher_51', 'School_5'): 19,
#  ('teacher_51', 'School_6'): 18,
#  ('teacher_51', 'School_7'): 11,
#  ('teacher_51', 'School_8'): 18,
#  ('teacher_51', 'School_9'): 14,
#  ('teacher_51', 'School_10'): 19,
#  ('teacher_52', 'School_1'): 8,
#  ('teacher_52', 'School_2'): 5,
#  ('teacher_52', 'School_3'): 5,
#  ('teacher_52', 'School_4'): 17,
#  ('teacher_52', 'School_5'): 13,
#  ('teacher_52', 'School_6'): 10,
#  ('teacher_52', 'School_7'): 15,
#  ('teacher_52', 'School_8'): 16,
#  ('teacher_52', 'School_9'): 8,
#  ('teacher_52', 'School_10'): 17,
#  ('teacher_53', 'School_1'): 11,
#  ('teacher_53', 'School_2'): 13,
#  ('teacher_53', 'School_3'): 4,
#  ('teacher_53', 'School_4'): 19,
#  ('teacher_53', 'School_5'): 18,
#  ('teacher_53', 'School_6'): 9,
#  ('teacher_53', 'School_7'): 4,
#  ('teacher_53', 'School_8'): 18,
#  ('teacher_53', 'School_9'): 11,
#  ('teacher_53', 'School_10'): 16,
#  ('teacher_54', 'School_1'): 4,
#  ('teacher_54', 'School_2'): 12,
#  ('teacher_54', 'School_3'): 3,
#  ('teacher_54', 'School_4'): 7,
#  ('teacher_54', 'School_5'): 14,
#  ('teacher_54', 'School_6'): 12,
#  ('teacher_54', 'School_7'): 2,
#  ('teacher_54', 'School_8'): 8,
#  ('teacher_54', 'School_9'): 9,
#  ('teacher_54', 'School_10'): 13,
#  ('teacher_55', 'School_1'): 19,
#  ('teacher_55', 'School_2'): 8,
#  ('teacher_55', 'School_3'): 5,
#  ('teacher_55', 'School_4'): 14,
#  ('teacher_55', 'School_5'): 17,
#  ('teacher_55', 'School_6'): 6,
#  ('teacher_55', 'School_7'): 2,
#  ('teacher_55', 'School_8'): 2,
#  ('teacher_55', 'School_9'): 16,
#  ('teacher_55', 'School_10'): 11,
#  ('teacher_56', 'School_1'): 14,
#  ('teacher_56', 'School_2'): 7,
#  ('teacher_56', 'School_3'): 14,
#  ('teacher_56', 'School_4'): 10,
#  ('teacher_56', 'School_5'): 9,
#  ('teacher_56', 'School_6'): 5,
#  ('teacher_56', 'School_7'): 11,
#  ('teacher_56', 'School_8'): 4,
#  ('teacher_56', 'School_9'): 5,
#  ('teacher_56', 'School_10'): 11,
#  ('teacher_57', 'School_1'): 15,
#  ('teacher_57', 'School_2'): 10,
#  ('teacher_57', 'School_3'): 18,
#  ('teacher_57', 'School_4'): 8,
#  ('teacher_57', 'School_5'): 12,
#  ('teacher_57', 'School_6'): 14,
#  ('teacher_57', 'School_7'): 12,
#  ('teacher_57', 'School_8'): 8,
#  ('teacher_57', 'School_9'): 5,
#  ('teacher_57', 'School_10'): 2,
#  ('teacher_58', 'School_1'): 13,
#  ('teacher_58', 'School_2'): 10,
#  ('teacher_58', 'School_3'): 12,
#  ('teacher_58', 'School_4'): 18,
#  ('teacher_58', 'School_5'): 9,
#  ('teacher_58', 'School_6'): 3,
#  ('teacher_58', 'School_7'): 5,
#  ('teacher_58', 'School_8'): 12,
#  ('teacher_58', 'School_9'): 16,
#  ('teacher_58', 'School_10'): 12,
#  ('teacher_59', 'School_1'): 18,
#  ('teacher_59', 'School_2'): 18,
#  ('teacher_59', 'School_3'): 4,
#  ('teacher_59', 'School_4'): 4,
#  ('teacher_59', 'School_5'): 17,
#  ('teacher_59', 'School_6'): 14,
#  ('teacher_59', 'School_7'): 9,
#  ('teacher_59', 'School_8'): 10,
#  ('teacher_59', 'School_9'): 3,
#  ('teacher_59', 'School_10'): 17,
#  ('teacher_60', 'School_1'): 4,
#  ('teacher_60', 'School_2'): 6,
#  ('teacher_60', 'School_3'): 13,
#  ('teacher_60', 'School_4'): 19,
#  ('teacher_60', 'School_5'): 14,
#  ('teacher_60', 'School_6'): 2,
#  ('teacher_60', 'School_7'): 16,
#  ('teacher_60', 'School_8'): 14,
#  ('teacher_60', 'School_9'): 17,
#  ('teacher_60', 'School_10'): 9,
#  ('teacher_61', 'School_1'): 12,
#  ('teacher_61', 'School_2'): 5,
#  ('teacher_61', 'School_3'): 8,
#  ('teacher_61', 'School_4'): 9,
#  ('teacher_61', 'School_5'): 4,
#  ('teacher_61', 'School_6'): 8,
#  ('teacher_61', 'School_7'): 3,
#  ('teacher_61', 'School_8'): 6,
#  ('teacher_61', 'School_9'): 5,
#  ('teacher_61', 'School_10'): 2,
#  ('teacher_62', 'School_1'): 19,
#  ('teacher_62', 'School_2'): 11,
#  ('teacher_62', 'School_3'): 16,
#  ('teacher_62', 'School_4'): 10,
#  ('teacher_62', 'School_5'): 19,
#  ('teacher_62', 'School_6'): 8,
#  ('teacher_62', 'School_7'): 10,
#  ('teacher_62', 'School_8'): 16,
#  ('teacher_62', 'School_9'): 12,
#  ('teacher_62', 'School_10'): 19,
#  ('teacher_63', 'School_1'): 14,
#  ('teacher_63', 'School_2'): 7,
#  ('teacher_63', 'School_3'): 5,
#  ('teacher_63', 'School_4'): 7,
#  ('teacher_63', 'School_5'): 3,
#  ('teacher_63', 'School_6'): 18,
#  ('teacher_63', 'School_7'): 6,
#  ('teacher_63', 'School_8'): 12,
#  ('teacher_63', 'School_9'): 7,
#  ('teacher_63', 'School_10'): 5,
#  ('teacher_64', 'School_1'): 11,
#  ('teacher_64', 'School_2'): 8,
#  ('teacher_64', 'School_3'): 10,
#  ('teacher_64', 'School_4'): 17,
#  ('teacher_64', 'School_5'): 6,
#  ('teacher_64', 'School_6'): 14,
#  ('teacher_64', 'School_7'): 12,
#  ('teacher_64', 'School_8'): 4,
#  ('teacher_64', 'School_9'): 17,
#  ('teacher_64', 'School_10'): 19,
#  ('teacher_65', 'School_1'): 18,
#  ('teacher_65', 'School_2'): 18,
#  ('teacher_65', 'School_3'): 16,
#  ('teacher_65', 'School_4'): 16,
#  ('teacher_65', 'School_5'): 8,
#  ('teacher_65', 'School_6'): 9,
#  ('teacher_65', 'School_7'): 17,
#  ('teacher_65', 'School_8'): 5,
#  ('teacher_65', 'School_9'): 6,
#  ('teacher_65', 'School_10'): 19,
#  ('teacher_66', 'School_1'): 15,
#  ('teacher_66', 'School_2'): 2,
#  ('teacher_66', 'School_3'): 2,
#  ('teacher_66', 'School_4'): 7,
#  ('teacher_66', 'School_5'): 14,
#  ('teacher_66', 'School_6'): 15,
#  ('teacher_66', 'School_7'): 4,
#  ('teacher_66', 'School_8'): 15,
#  ('teacher_66', 'School_9'): 15,
#  ('teacher_66', 'School_10'): 7,
#  ('teacher_67', 'School_1'): 16,
#  ('teacher_67', 'School_2'): 7,
#  ('teacher_67', 'School_3'): 5,
#  ('teacher_67', 'School_4'): 12,
#  ('teacher_67', 'School_5'): 18,
#  ('teacher_67', 'School_6'): 5,
#  ('teacher_67', 'School_7'): 14,
#  ('teacher_67', 'School_8'): 12,
#  ('teacher_67', 'School_9'): 16,
#  ('teacher_67', 'School_10'): 7,
#  ('teacher_68', 'School_1'): 6,
#  ('teacher_68', 'School_2'): 10,
#  ('teacher_68', 'School_3'): 14,
#  ('teacher_68', 'School_4'): 4,
#  ('teacher_68', 'School_5'): 8,
#  ('teacher_68', 'School_6'): 12,
#  ('teacher_68', 'School_7'): 10,
#  ('teacher_68', 'School_8'): 4,
#  ('teacher_68', 'School_9'): 14,
#  ('teacher_68', 'School_10'): 7,
#  ('teacher_69', 'School_1'): 3,
#  ('teacher_69', 'School_2'): 10,
#  ('teacher_69', 'School_3'): 16,
#  ('teacher_69', 'School_4'): 5,
#  ('teacher_69', 'School_5'): 9,
#  ('teacher_69', 'School_6'): 5,
#  ('teacher_69', 'School_7'): 5,
#  ('teacher_69', 'School_8'): 9,
#  ('teacher_69', 'School_9'): 15,
#  ('teacher_69', 'School_10'): 5,
#  ('teacher_70', 'School_1'): 7,
#  ('teacher_70', 'School_2'): 6,
#  ('teacher_70', 'School_3'): 4,
#  ('teacher_70', 'School_4'): 10,
#  ('teacher_70', 'School_5'): 12,
#  ('teacher_70', 'School_6'): 6,
#  ('teacher_70', 'School_7'): 9,
#  ('teacher_70', 'School_8'): 7,
#  ('teacher_70', 'School_9'): 5,
#  ('teacher_70', 'School_10'): 16,
#  ('teacher_71', 'School_1'): 5,
#  ('teacher_71', 'School_2'): 10,
#  ('teacher_71', 'School_3'): 19,
#  ('teacher_71', 'School_4'): 6,
#  ('teacher_71', 'School_5'): 12,
#  ('teacher_71', 'School_6'): 9,
#  ('teacher_71', 'School_7'): 14,
#  ('teacher_71', 'School_8'): 13,
#  ('teacher_71', 'School_9'): 4,
#  ('teacher_71', 'School_10'): 10,
#  ('teacher_72', 'School_1'): 9,
#  ('teacher_72', 'School_2'): 11,
#  ('teacher_72', 'School_3'): 10,
#  ('teacher_72', 'School_4'): 19,
#  ('teacher_72', 'School_5'): 18,
#  ('teacher_72', 'School_6'): 19,
#  ('teacher_72', 'School_7'): 17,
#  ('teacher_72', 'School_8'): 15,
#  ('teacher_72', 'School_9'): 2,
#  ('teacher_72', 'School_10'): 13,
#  ('teacher_73', 'School_1'): 7,
#  ('teacher_73', 'School_2'): 4,
#  ('teacher_73', 'School_3'): 2,
#  ('teacher_73', 'School_4'): 11,
#  ('teacher_73', 'School_5'): 5,
#  ('teacher_73', 'School_6'): 9,
#  ('teacher_73', 'School_7'): 6,
#  ('teacher_73', 'School_8'): 5,
#  ('teacher_73', 'School_9'): 8,
#  ('teacher_73', 'School_10'): 8,
#  ('teacher_74', 'School_1'): 16,
#  ('teacher_74', 'School_2'): 9,
#  ('teacher_74', 'School_3'): 9,
#  ('teacher_74', 'School_4'): 12,
#  ('teacher_74', 'School_5'): 11,
#  ('teacher_74', 'School_6'): 18,
#  ('teacher_74', 'School_7'): 9,
#  ('teacher_74', 'School_8'): 14,
#  ('teacher_74', 'School_9'): 10,
#  ('teacher_74', 'School_10'): 2,
#  ('teacher_75', 'School_1'): 18,
#  ('teacher_75', 'School_2'): 2,
#  ('teacher_75', 'School_3'): 8,
#  ('teacher_75', 'School_4'): 11,
#  ('teacher_75', 'School_5'): 13,
#  ('teacher_75', 'School_6'): 12,
#  ('teacher_75', 'School_7'): 4,
#  ('teacher_75', 'School_8'): 7,
#  ('teacher_75', 'School_9'): 5,
#  ('teacher_75', 'School_10'): 14,
#  ('teacher_76', 'School_1'): 9,
#  ('teacher_76', 'School_2'): 17,
#  ('teacher_76', 'School_3'): 6,
#  ('teacher_76', 'School_4'): 13,
#  ('teacher_76', 'School_5'): 5,
#  ('teacher_76', 'School_6'): 4,
#  ('teacher_76', 'School_7'): 9,
#  ('teacher_76', 'School_8'): 17,
#  ('teacher_76', 'School_9'): 15,
#  ('teacher_76', 'School_10'): 9,
#  ('teacher_77', 'School_1'): 8,
#  ('teacher_77', 'School_2'): 14,
#  ('teacher_77', 'School_3'): 16,
#  ('teacher_77', 'School_4'): 19,
#  ('teacher_77', 'School_5'): 2,
#  ('teacher_77', 'School_6'): 14,
#  ('teacher_77', 'School_7'): 7,
#  ('teacher_77', 'School_8'): 10,
#  ('teacher_77', 'School_9'): 15,
#  ('teacher_77', 'School_10'): 10,
#  ('teacher_78', 'School_1'): 6,
#  ('teacher_78', 'School_2'): 5,
#  ('teacher_78', 'School_3'): 4,
#  ('teacher_78', 'School_4'): 13,
#  ('teacher_78', 'School_5'): 7,
#  ('teacher_78', 'School_6'): 12,
#  ('teacher_78', 'School_7'): 11,
#  ('teacher_78', 'School_8'): 18,
#  ('teacher_78', 'School_9'): 8,
#  ('teacher_78', 'School_10'): 12,
#  ('teacher_79', 'School_1'): 4,
#  ('teacher_79', 'School_2'): 9,
#  ('teacher_79', 'School_3'): 15,
#  ('teacher_79', 'School_4'): 12,
#  ('teacher_79', 'School_5'): 11,
#  ('teacher_79', 'School_6'): 2,
#  ('teacher_79', 'School_7'): 18,
#  ('teacher_79', 'School_8'): 4,
#  ('teacher_79', 'School_9'): 10,
#  ('teacher_79', 'School_10'): 4,
#  ('teacher_80', 'School_1'): 18,
#  ('teacher_80', 'School_2'): 6,
#  ('teacher_80', 'School_3'): 3,
#  ('teacher_80', 'School_4'): 14,
#  ('teacher_80', 'School_5'): 15,
#  ('teacher_80', 'School_6'): 9,
#  ('teacher_80', 'School_7'): 11,
#  ('teacher_80', 'School_8'): 13,
#  ('teacher_80', 'School_9'): 4,
#  ('teacher_80', 'School_10'): 11,
#  ('teacher_81', 'School_1'): 17,
#  ('teacher_81', 'School_2'): 7,
#  ('teacher_81', 'School_3'): 12,
#  ('teacher_81', 'School_4'): 7,
#  ('teacher_81', 'School_5'): 12,
#  ('teacher_81', 'School_6'): 16,
#  ('teacher_81', 'School_7'): 9,
#  ('teacher_81', 'School_8'): 17,
#  ('teacher_81', 'School_9'): 18,
#  ('teacher_81', 'School_10'): 18,
#  ('teacher_82', 'School_1'): 6,
#  ('teacher_82', 'School_2'): 11,
#  ('teacher_82', 'School_3'): 10,
#  ('teacher_82', 'School_4'): 10,
#  ('teacher_82', 'School_5'): 5,
#  ('teacher_82', 'School_6'): 7,
#  ('teacher_82', 'School_7'): 18,
#  ('teacher_82', 'School_8'): 16,
#  ('teacher_82', 'School_9'): 4,
#  ('teacher_82', 'School_10'): 5,
#  ('teacher_83', 'School_1'): 5,
#  ('teacher_83', 'School_2'): 7,
#  ('teacher_83', 'School_3'): 3,
#  ('teacher_83', 'School_4'): 10,
#  ('teacher_83', 'School_5'): 11,
#  ('teacher_83', 'School_6'): 5,
#  ('teacher_83', 'School_7'): 10,
#  ('teacher_83', 'School_8'): 2,
#  ('teacher_83', 'School_9'): 10,
#  ('teacher_83', 'School_10'): 16,
#  ('teacher_84', 'School_1'): 5,
#  ('teacher_84', 'School_2'): 9,
#  ('teacher_84', 'School_3'): 4,
#  ('teacher_84', 'School_4'): 3,
#  ('teacher_84', 'School_5'): 19,
#  ('teacher_84', 'School_6'): 18,
#  ('teacher_84', 'School_7'): 9,
#  ('teacher_84', 'School_8'): 8,
#  ('teacher_84', 'School_9'): 3,
#  ('teacher_84', 'School_10'): 6,
#  ('teacher_85', 'School_1'): 17,
#  ('teacher_85', 'School_2'): 15,
#  ('teacher_85', 'School_3'): 11,
#  ('teacher_85', 'School_4'): 10,
#  ('teacher_85', 'School_5'): 2,
#  ('teacher_85', 'School_6'): 10,
#  ('teacher_85', 'School_7'): 17,
#  ('teacher_85', 'School_8'): 13,
#  ('teacher_85', 'School_9'): 4,
#  ('teacher_85', 'School_10'): 4,
#  ('teacher_86', 'School_1'): 9,
#  ('teacher_86', 'School_2'): 4,
#  ('teacher_86', 'School_3'): 4,
#  ('teacher_86', 'School_4'): 2,
#  ('teacher_86', 'School_5'): 11,
#  ('teacher_86', 'School_6'): 15,
#  ('teacher_86', 'School_7'): 10,
#  ('teacher_86', 'School_8'): 19,
#  ('teacher_86', 'School_9'): 16,
#  ('teacher_86', 'School_10'): 9,
#  ('teacher_87', 'School_1'): 18,
#  ('teacher_87', 'School_2'): 10,
#  ('teacher_87', 'School_3'): 8,
#  ('teacher_87', 'School_4'): 7,
#  ('teacher_87', 'School_5'): 18,
#  ('teacher_87', 'School_6'): 2,
#  ('teacher_87', 'School_7'): 4,
#  ('teacher_87', 'School_8'): 9,
#  ('teacher_87', 'School_9'): 17,
#  ('teacher_87', 'School_10'): 7,
#  ('teacher_88', 'School_1'): 4,
#  ('teacher_88', 'School_2'): 11,
#  ('teacher_88', 'School_3'): 10,
#  ('teacher_88', 'School_4'): 17,
#  ('teacher_88', 'School_5'): 19,
#  ('teacher_88', 'School_6'): 2,
#  ('teacher_88', 'School_7'): 13,
#  ('teacher_88', 'School_8'): 7,
#  ('teacher_88', 'School_9'): 19,
#  ('teacher_88', 'School_10'): 2,
#  ('teacher_89', 'School_1'): 8,
#  ('teacher_89', 'School_2'): 5,
#  ('teacher_89', 'School_3'): 6,
#  ('teacher_89', 'School_4'): 10,
#  ('teacher_89', 'School_5'): 14,
#  ('teacher_89', 'School_6'): 11,
#  ('teacher_89', 'School_7'): 17,
#  ('teacher_89', 'School_8'): 14,
#  ('teacher_89', 'School_9'): 10,
#  ('teacher_89', 'School_10'): 16,
#  ('teacher_90', 'School_1'): 15,
#  ('teacher_90', 'School_2'): 10,
#  ('teacher_90', 'School_3'): 5,
#  ('teacher_90', 'School_4'): 13,
#  ('teacher_90', 'School_5'): 13,
#  ('teacher_90', 'School_6'): 3,
#  ('teacher_90', 'School_7'): 4,
#  ('teacher_90', 'School_8'): 15,
#  ('teacher_90', 'School_9'): 5,
#  ('teacher_90', 'School_10'): 16,
#  ('teacher_91', 'School_1'): 4,
#  ('teacher_91', 'School_2'): 14,
#  ('teacher_91', 'School_3'): 9,
#  ('teacher_91', 'School_4'): 11,
#  ('teacher_91', 'School_5'): 10,
#  ('teacher_91', 'School_6'): 4,
#  ('teacher_91', 'School_7'): 5,
#  ('teacher_91', 'School_8'): 14,
#  ('teacher_91', 'School_9'): 16,
#  ('teacher_91', 'School_10'): 7,
#  ('teacher_92', 'School_1'): 12,
#  ('teacher_92', 'School_2'): 13,
#  ('teacher_92', 'School_3'): 6,
#  ('teacher_92', 'School_4'): 3,
#  ('teacher_92', 'School_5'): 2,
#  ('teacher_92', 'School_6'): 18,
#  ('teacher_92', 'School_7'): 8,
#  ('teacher_92', 'School_8'): 10,
#  ('teacher_92', 'School_9'): 4,
#  ('teacher_92', 'School_10'): 8,
#  ('teacher_93', 'School_1'): 6,
#  ('teacher_93', 'School_2'): 17,
#  ('teacher_93', 'School_3'): 17,
#  ('teacher_93', 'School_4'): 17,
#  ('teacher_93', 'School_5'): 13,
#  ('teacher_93', 'School_6'): 8,
#  ('teacher_93', 'School_7'): 4,
#  ('teacher_93', 'School_8'): 19,
#  ('teacher_93', 'School_9'): 2,
#  ('teacher_93', 'School_10'): 9,
#  ('teacher_94', 'School_1'): 5,
#  ('teacher_94', 'School_2'): 17,
#  ('teacher_94', 'School_3'): 18,
#  ('teacher_94', 'School_4'): 2,
#  ('teacher_94', 'School_5'): 14,
#  ('teacher_94', 'School_6'): 6,
#  ('teacher_94', 'School_7'): 10,
#  ('teacher_94', 'School_8'): 8,
#  ('teacher_94', 'School_9'): 13,
#  ('teacher_94', 'School_10'): 3,
#  ('teacher_95', 'School_1'): 15,
#  ('teacher_95', 'School_2'): 19,
#  ('teacher_95', 'School_3'): 18,
#  ('teacher_95', 'School_4'): 8,
#  ('teacher_95', 'School_5'): 11,
#  ('teacher_95', 'School_6'): 11,
#  ('teacher_95', 'School_7'): 2,
#  ('teacher_95', 'School_8'): 6,
#  ('teacher_95', 'School_9'): 3,
#  ('teacher_95', 'School_10'): 9,
#  ('teacher_96', 'School_1'): 9,
#  ('teacher_96', 'School_2'): 11,
#  ('teacher_96', 'School_3'): 10,
#  ('teacher_96', 'School_4'): 11,
#  ('teacher_96', 'School_5'): 9,
#  ('teacher_96', 'School_6'): 12,
#  ('teacher_96', 'School_7'): 11,
#  ('teacher_96', 'School_8'): 16,
#  ('teacher_96', 'School_9'): 9,
#  ('teacher_96', 'School_10'): 6,
#  ('teacher_97', 'School_1'): 8,
#  ('teacher_97', 'School_2'): 13,
#  ('teacher_97', 'School_3'): 14,
#  ('teacher_97', 'School_4'): 17,
#  ('teacher_97', 'School_5'): 4,
#  ('teacher_97', 'School_6'): 3,
#  ('teacher_97', 'School_7'): 14,
#  ('teacher_97', 'School_8'): 6,
#  ('teacher_97', 'School_9'): 9,
#  ('teacher_97', 'School_10'): 7,
#  ('teacher_98', 'School_1'): 7,
#  ('teacher_98', 'School_2'): 15,
#  ('teacher_98', 'School_3'): 15,
#  ('teacher_98', 'School_4'): 17,
#  ('teacher_98', 'School_5'): 10,
#  ('teacher_98', 'School_6'): 11,
#  ('teacher_98', 'School_7'): 5,
#  ('teacher_98', 'School_8'): 17,
#  ('teacher_98', 'School_9'): 17,
#  ('teacher_98', 'School_10'): 12,
#  ('teacher_99', 'School_1'): 13,
#  ('teacher_99', 'School_2'): 15,
#  ('teacher_99', 'School_3'): 11,
#  ('teacher_99', 'School_4'): 14,
#  ('teacher_99', 'School_5'): 12,
#  ('teacher_99', 'School_6'): 3,
#  ('teacher_99', 'School_7'): 11,
#  ('teacher_99', 'School_8'): 6,
#  ('teacher_99', 'School_9'): 3,
#  ('teacher_99', 'School_10'): 15,
#  ('teacher_100', 'School_1'): 18,
#  ('teacher_100', 'School_2'): 7,
#  ('teacher_100', 'School_3'): 17,
#  ('teacher_100', 'School_4'): 6,
#  ('teacher_100', 'School_5'): 10,
#  ('teacher_100', 'School_6'): 3,
#  ('teacher_100', 'School_7'): 8,
#  ('teacher_100', 'School_8'): 15,
#  ('teacher_100', 'School_9'): 16,
#  ('teacher_100', 'School_10'): 16}

# %%
#Now we should define our objective function. It is a distance for each teacher from each school. We want to minimize it.
m.setObjective(x.prod(obj_func), GRB.MINIMIZE)

# %%
#We can save our model
# save model for inspection - you can see it in folder of this task.
m.write('TEACHERS.lp')

# %%
# run optimisation engine
m.optimize()
# Out:
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 111 rows, 1000 columns and 3000 nonzeros
# Model fingerprint: 0xf363be96
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+05]
# Presolve time: 0.01s
# Presolved: 111 rows, 1000 columns, 3000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.000000e+01   0.000000e+00      0s
#       10    2.0000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.000000000e+01

# %%
#display optimal values of desicion variables:
#we print which teachers our solver selected for each school
for var in m.getVars():
    if var.x==1:
        print(var.varName, var.x)
# Out:
# assign[teacher_6,School_2] 1.0
# assign[teacher_12,School_1] 1.0
# assign[teacher_16,School_6] 1.0
# assign[teacher_38,School_8] 1.0
# assign[teacher_54,School_7] 1.0
# assign[teacher_61,School_10] 1.0
# assign[teacher_66,School_3] 1.0
# assign[teacher_72,School_9] 1.0
# assign[teacher_85,School_5] 1.0
# assign[teacher_94,School_4] 1.0

# %%
#We basically solved the problem. Teacher 6 goes to school 2, teacher 12 to school 1, etc. 
#Maybe we could see values of our objective function:

# %%
#display optimal matching score
print('total optimised distance', m.ObjVal)
print('average distance of all teachers', df['total_distance'].mean())
# Out:
# total optimised distance 20.0
# average distance of all teachers 92.86

# %% [markdown]
# It was easy for our solver to solve this. It is easy problem. Imagine now that we have 100 schools and 1000 teachers. The procedure would be completely the same.
